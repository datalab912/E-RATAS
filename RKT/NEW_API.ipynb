# %%
import os
from dotenv import load_dotenv

from GPT_assistant.base_assistant import BaseAssistant
from log_engine.log import Log
from utilities.utils import save_to_env_file

# %%
#from utils import save_to_env_file

load_dotenv()  # Load environment variables

TM_MODEL = "gpt-4-0125-preview"
TM_MODEL_NAME = "TM_ASSISTANT"
TM_MODEL_ID = f"{TM_MODEL_NAME}_ID"
TM_THREAD_ID = f"{TM_MODEL_NAME}_THREAD_ID"
# === Create Assistant ===


class TM_Assistant(BaseAssistant):
    ASSISTANT_INSTRUCTIONS = """You are an expert that work on a rubric criterion and divided it to some simpler criteria"""
    CREATE_THREAD_MESSAGE = """Divide the provided rubric criterion into distinct sub-criteria. Each sub-criterion should cover a different topic or area within the original criterion. All sub-criteria must be grouped under the same level of detail, able to reconstruct the original criterion when combined (except for exact duplications). Begin each sub-criterion with three asterisks (***). If the criterion is indivisible due to its homogeneous content, return it unchanged."""
    SINGLE_TASK = """concider these 7 instruction during the the criterion devision: 
    1- Read the Criterion Thoroughly: Understand the overall theme and elements of the criterion.
    2- Identify Distinct Areas: Look for distinct topics or areas within the criterion that can be separated.
    3- Construct Sub-Criteria: Create sub-criteria that focus on these distinct areas, ensuring each is comprehensive and preserves the content of the original criterion.
    4- Distinct Sections: Each sub-criterion should focus on a unique area. Use "***" to start each sub-criterion.
    5- Format the Output: Start each sub-criterion with "***" to indicate a new section.
    7- Check Completeness: Ensure that all sub-criteria together cover the entire content of the original criterion without redundancy.
    8- Return Unchanged if Indivisible: If no distinct areas can be identified, return the original criterion unchanged."""
    EXAMPLE_MESSAGE = "Please follow this example:\n\n"

    def __init__(self, assistant_id=None, thread_id=None):

        logger = Log("TM_v2_Assistant", "tm_v2_assistant.log")
        super().__init__(TM_MODEL_NAME, assistant_id, thread_id, logger)

        ASSISTANT_ID = os.getenv(TM_MODEL_ID)
        THREAD_ID = os.getenv(TM_THREAD_ID)

        if not ASSISTANT_ID and not assistant_id:
            ASSISTANT_ID = self.create_assistant(
                TM_MODEL_NAME, self.ASSISTANT_INSTRUCTIONS, TM_MODEL
            )
            save_to_env_file(TM_MODEL_ID, ASSISTANT_ID)

        if not THREAD_ID and not thread_id:
            THREAD_ID = self.create_thread()
            save_to_env_file(TM_THREAD_ID, THREAD_ID)

        self.assistant_id = ASSISTANT_ID or assistant_id
        self.thread_id = THREAD_ID or thread_id

    def run_assistant_single_text(self, instructions=None):
        run = self.client.beta.threads.runs.create(
            thread_id=self.thread_id,
            assistant_id=self.assistant_id,
            instructions=instructions or self.SINGLE_TASK,
        )
        self.logger.info(f"Assistant run created with ID: {run.id}")
        return self.wait_for_run_completion(run.id)

    def add_example_by_batching(self, examples: list):
        for example in examples:
            self.add_example_to_thread(example["input"], example["output"])

# %%
import os

# Print all environment variables
for key, value in os.environ.items():
    print(f"{key}: {value}")

# %%
from GPT_assistant.topic_modelling import TM_Assistant
assistant = TM_Assistant()
print(assistant.thread_id)
# Out:
# thread_xRltMVZBXDWLk1bxOheoHFma

# %%
assistant.add_message_to_thread("The provided rubric criterion is:\n" + "Acknodlegment section have content related to aknowledge  the help and support of all the people who helped you in completion of your internship and internship report")
output = assistant.run_assistant_single_time()
messages = assistant.client.beta.threads.messages.list(
    thread_id = assistant.thread_id,
    )
for message in reversed (messages.data):
  print(message.role + ":" + message.content[0].text.value)
print (len (messages.data))

# %%
assistant.add_message_to_thread("very good, do agin for this criteria is:\n" + "the document should have overview of the organization Section(essential) \n overview of Organization Section sould cover these content: \n a. Brief history \n b. Introduction of the organization")
output = assistant.run_assistant_single_time()
messages = assistant.client.beta.threads.messages.list(
    thread_id = assistant.thread_id,
    )
for message in reversed (messages.data):
  print(message.role + ":" + message.content[0].text.value)
print (len (messages.data))

# %%
assistant.add_message_to_thread("very good, do agian for this criteria is:\n" + "The document should have Plan of your internship program Scetion (essential) \n Plan of your internship program Scetion sould cover these contents: \n a. A brief introduction of the branch/ area office of the organization where you did your internship \n b. Starting and ending dates of your internship")
output = assistant.run_assistant_single_time()
messages = assistant.client.beta.threads.messages.list(
    thread_id = assistant.thread_id,
    )
for message in reversed (messages.data):
  print(message.role + ":" + message.content[0].text.value)
print (len (messages.data))

# %%
assistant.add_message_to_thread("very good, do agin for this criteria is:\n" + "for all events or happening or obeservation: \n - answer “What did you, see, read, hear etc? related to events or happening or obeservation \n - describe Objectivity andhypotheses of events or happening or obeservation \n - Describe the student's conclusions of events or happening or obeservation \n - Answer the question what might the events or happening or obeservation mean?  \n - Describe the student's judgments clearly connected to events or happening or obeservation")
output = assistant.run_assistant_single_time()
messages = assistant.client.beta.threads.messages.list(
    thread_id = assistant.thread_id,
    )
for message in reversed (messages.data):
  print(message.role + ":" + message.content[0].text.value)
print (len (messages.data))

# %%
assistant.add_message_to_thread("very good, do agian for this criteria is:\n" + "The document should have Plan of your internship program Scetion (essential) \n Plan of your internship program Scetion sould cover these contents: \n a. A brief introduction of the branch/ area office of the organization where you did your internship \n b. Starting and ending dates of your internship")
output = assistant.run_assistant_single_time()
messages = assistant.client.beta.threads.messages.list(
    thread_id = assistant.thread_id,
    )
for message in reversed (messages.data):
  print(message.role + ":" + message.content[0].text.value)
print (len (messages.data))

# %%
assistant.add_message_to_thread("very good, do agian for this criteria is:\n" + "The document should have Plan of your internship program Scetion (essential) \n Plan of your internship program Scetion sould cover these contents: \n a. A brief introduction of the branch/ area office of the organization where you did your internship \n b. Starting and ending dates of your internship")
output = assistant.run_assistant_single_time()
messages = assistant.client.beta.threads.messages.list(
    thread_id = assistant.thread_id,
    )
for message in reversed (messages.data):
  print(message.role + ":" + message.content[0].text.value)
print (len (messages.data))

# %%
assistant.add_message_to_thread("very good, do agian for this criteria is:\n" + "The document should have Plan of your internship program Scetion (essential) \n Plan of your internship program Scetion sould cover these contents: \n a. A brief introduction of the branch/ area office of the organization where you did your internship \n b. Starting and ending dates of your internship")
output = assistant.run_assistant_single_time()
messages = assistant.client.beta.threads.messages.list(
    thread_id = assistant.thread_id,
    )
i=0
for message in reversed (messages.data):
  i=i+1
  print(i)
  print(message.role + ":" + message.content[0].text.value)
print (len (messages.data))

# %%
assistant.add_message_to_thread("very good, do agian for this criteria is:\n" + "The document should have Plan of your internship program Scetion (essential) \n Plan of your internship program Scetion sould cover these contents: \n a. A brief introduction of the branch/ area office of the organization where you did your internship \n b. Starting and ending dates of your internship")
output = assistant.run_assistant_single_time()
messages = assistant.client.beta.threads.messages.list(
    thread_id = assistant.thread_id,
    )
i=0
for message in reversed (messages.data):
  i=i+1
  print(i)
  print(message.role + ":" + message.content[0].text.value)
print (len (messages.data))

# %%
from GPT_assistant.criteria_titling import CT_Assistant
assistant = CT_Assistant()
print(assistant.thread_id)
# Out:
# There is no thread id, adding examples to thread.
# thread_si1YgId0tf1mDtheN8T51AiV

# %%
assistant.add_message_to_thread("very good, do agian for this criteria is:\n" + "The document should have Plan of your internship program Scetion (essential) \n Plan of your internship program Scetion sould cover these contents: \n a. A brief introduction of the branch/ area office of the organization where you did your internship \n b. Starting and ending dates of your internship")
output = assistant.run_assistant_single_time()
messages = assistant.client.beta.threads.messages.list(
    thread_id = assistant.thread_id,
    )
i=0
for message in reversed (messages.data):
  i=i+1
  print(i)
  print(message.role + ":" + message.content[0].text.value)
print (len (messages.data))

# %%
from GPT_assistant.topic_modelling import TM_Assistant
assistant = TM_Assistant()

# %%
messages = assistant.client.beta.threads.messages.list(
    thread_id = assistant.thread_id,
    )
i=0
for message in reversed (messages.data):
  i=i+1
  print(i)
  print(message.role + ":" + message.content[0].text.value)
print (len (messages.data))
# Out:
# 1
# assistant:***Conclusions Regarding Week 2 Events, Happenings, or Observations
#     ***Summarizing the student's insights and interpretations of the observed events or happenings in Week 2
#     ***Formulating conclusions based on the analysis and observations made during Week 2
#     ***Providing reflections on the significance and implications of the events or observations in Week 2
# 2
# user:very good, do again for the next provided rubric criterion:
# Connection and Communication Experience Evaluationlike the previous message, follow the instructions and examples to generate the the related sub-criteria
# 3
# assistant:***Connection and Communication Experience Evaluation
#     ***Assessing the effectiveness of connections and communication with others and organizations
#     ***Evaluating the efficiency of interactions and exchanges during the internship
#     ***Reflecting on the overall experience of connection and communication and identifying areas for improvement
# 4
# user:very good, do again for the next provided rubric criterion:
# Assessment of the effectiveness and efficiency of connection and communication in Week 2 with others and organizationslike the previous message, follow the instructions and examples to generate the the related sub-criteria
# 5
# assistant:***Assessment of the Effectiveness and Efficiency of Connection and Communication in Week 2 with Others and Organizations
#     ***Evaluating how effectively connections and communication were established and maintained in Week 2
#     ***Assessing the efficiency of the interactions with others and organizations during Week 2
#     ***Analyzing the impact of effective communication and connections on the overall Week 2 experience
# 6
# user:very good, do again for the next provided rubric criterion:
# Student's conclusions and feelings about connection and communication with others and organizations in Week 2like the previous message, follow the instructions and examples to generate the the related sub-criteria
# 7
# user:very good, do again for the next provided rubric criterion:
# The document should be divided to 3 subsections from week 1 to week 3 subsections (essemtial)
#
# for all subsections related to weeks from 1 to 3, the subsections should cover related information about 1- at least one assignment or tasks or activities 2- at least one happenings or events or observation 3- at least one connection and Communication experience with others and organizations. like the previous message, follow the instructions and examples to generate the the related sub-criteria
# 8
# assistant:***Division into Week 1 to Week 3 Subsections (essential)
#     ***Week 1 Subsection Analysis
#         ***Assessment of at least one assignment or tasks or activities in Week 1
#         ***Description of at least one happenings or events or observation in Week 1
#         ***Evaluation of at least one connection and communication experience with others and organizations in Week 1
#     ***Week 2 Subsection Analysis
#         ***Assessment of at least one assignment or tasks or activities in Week 2
#         ***Description of at least one happenings or events or observation in Week 2
#         ***Evaluation of at least one connection and communication experience with others and organizations in Week 2
#     ***Week 3 Subsection Analysis
#         ***Assessment of at least one assignment or tasks or activities in Week 3
#         ***Description of at least one happenings or events or observation in Week 3
#         ***Evaluation of at least one connection and communication experience with others and organizations in Week 3
# 9
# user:very good, do again for the next provided rubric criterion:
# For all subsection week 1 to week 3 the information related to 1- assignment or tasks or activities 2- happenings or events or observation 3- connection and Communication experience with others and organizations should cover these contents:
#
# for all tasks and assignments and activities, describe:
# - Evaluate the effectiveness and efficiency of the tasks or assignments or activities
# -Describe objectively, hypotheses of the tasks or assignments or activities
#
#
# for all events or happening or observation:
# - answer “What did you, see, read, hear etc.? related to events or happening or observation
# - describe Objectivity and hypotheses of events or happening or observation
# - Describe the student's conclusions of events or happening or observation
#
#
# For all connection and Communication experience with others and organizations:
# - Evaluate the effectiveness and efficiency of connection and Communication experience with others and organizations
# - Describe the student's conclusions about connection and Communication experience with others and organizations
# - Describe the student's feelings about connection and Communication experience with others and organizations
# -Describe In what ways the learning experience related to connection and Communication experience with others and organizations will serve the student in his/her futurelike the previous message, follow the instructions and examples to generate the the related sub-criteria
# 10
# assistant:***Evaluation and Description Criteria for Week 1 to Week 3 Subsections
#     ***Evaluation and Description for Tasks, Assignments, or Activities
#         ***Assessing the effectiveness and efficiency of tasks, assignments, or activities in Week 1, Week 2, and Week 3
#         ***Providing objective descriptions and hypotheses related to tasks, assignments, or activities for each week
#     ***Observations and Events Analysis
#         ***Detailing observations and events for Week 1, Week 2, and Week 3
#         ***Analyzing events or happenings objectively and proposing hypotheses for each week
#         ***Summarizing conclusions drawn from events or happenings in each week
#     ***Connection and Communication Experience Assessment
#         ***Evaluating the effectiveness and efficiency of connection and communication experience in each week
#         ***Describing the student's conclusions and reflections on connection and communication with others and organizations for Week 1, Week 2, and Week 3
#         ***Discussing the student's feelings about connection and communication experiences and highlighting how these experiences will benefit the student in future endeavors for each week
# 11
# user:very good, do again for the next provided rubric criterion:
# Division into Week 1 to Week 3 Subsections (essential)like the previous message, follow the instructions and examples to generate the the related sub-criteria
# 12
# assistant:***Division into Week 1 to Week 3 Subsections (essential)
#     ***Week 1 Subsection Analysis
#         ***Assessment of assignments, tasks, or activities in Week 1
#         ***Description of happenings, events, or observations in Week 1
#         ***Evaluation of connection and communication experience with others and organizations in Week 1
#     ***Week 2 Subsection Analysis
#         ***Assessment of assignments, tasks, or activities in Week 2
#         ***Description of happenings, events, or observations in Week 2
#         ***Evaluation of connection and communication experience with others and organizations in Week 2
#     ***Week 3 Subsection Analysis
#         ***Assessment of assignments, tasks, or activities in Week 3
#         ***Description of happenings, events, or observations in Week 3
#         ***Evaluation of connection and communication experience with others and organizations in Week 3
# 13
# user:very good, do again for the next provided rubric criterion:
# Week 1 Subsection Analysislike the previous message, follow the instructions and examples to generate the the related sub-criteria
# 14
# assistant:***Week 1 Subsection Analysis
#     ***Evaluation and Description for Week 1 Assignments, Tasks, or Activities
#         ***Assessing the effectiveness and efficiency of tasks, assignments, or activities in Week 1
#         ***Detailing objective descriptions and hypotheses related to Week 1 tasks, assignments, or activities
#     ***Observations and Events Analysis for Week 1
#         ***Accounting for what was seen, read, heard, etc. in events, happenings, or observations during Week 1
#         ***Providing an objective analysis with hypotheses related to Week 1 events, happenings, or observations
#         ***Summarizing conclusions drawn by the student regarding Week 1 events, happenings, or observations
#     ***Connection and Communication Experience Evaluation in Week 1
#         ***Assessing the effectiveness and efficiency of connection and communication with others and organizations in Week 1
#         ***Describing conclusions and reflections on the connection and communication experiences in Week 1
#         ***Explaining the student's feelings about connection and communication experiences and their potential impact on future endeavors in Week 1
# 15
# user:The new provided rubric criterion is:
# The document should be divided to 3 subsections from week 1 to week 3 subsections (essemtial)
#
# for all subsections related to weeks from 1 to 3, the subsections should cover related information about 1- at least one assignment or tasks or activities 2- at least one happenings or events or observation 3- at least one connection and Communication experience with others and organizations.
#  follow the instructions of this thread and examples (provided at the first messages of this thread) to generate the sub-criteria for the next criterion
# 16
# assistant:***Division into Week 1 to Week 3 Subsections (essential)
#     ***Week 1 Subsection Details
#         ***Analysis of at least one assignment, tasks, or activities in Week 1
#         ***Discussion of at least one happenings, events, or observations in Week 1
#         ***Evaluation of at least one connection and communication experience with others and organizations in Week 1
#     ***Week 2 Subsection Details
#         ***Analysis of at least one assignment, tasks, or activities in Week 2
#         ***Discussion of at least one happenings, events, or observations in Week 2
#         ***Evaluation of at least one connection and communication experience with others and organizations in Week 2
#     ***Week 3 Subsection Details
#         ***Analysis of at least one assignment, tasks, or activities in Week 3
#         ***Discussion of at least one happenings, events, or observations in Week 3
#         ***Evaluation of at least one connection and communication experience with others and organizations in Week 3
# 17
# user:The new provided rubric criterion is:
# For all subsection week 1 to week 3 the information related to 1- assignment or tasks or activities 2- happenings or events or observation 3- connection and Communication experience with others and organizations should cover these contents:
#
# for all tasks and assignments and activities, describe:
# - Evaluate the effectiveness and efficiency of the tasks or assignments or activities
# -Describe objectively, hypotheses of the tasks or assignments or activities
#
#
# for all events or happening or observation:
# - answer “What did you, see, read, hear etc.? related to events or happening or observation
# - describe Objectivity and hypotheses of events or happening or observation
# - Describe the student's conclusions of events or happening or observation
#
#
# For all connection and Communication experience with others and organizations:
# - Evaluate the effectiveness and efficiency of connection and Communication experience with others and organizations
# - Describe the student's conclusions about connection and Communication experience with others and organizations
# - Describe the student's feelings about connection and Communication experience with others and organizations
# -Describe In what ways the learning experience related to connection and Communication experience with others and organizations will serve the student in his/her future
#  follow the instructions of this thread and examples (provided at the first messages of this thread) to generate the sub-criteria for the next criterion
# 18
# assistant:***Evaluation and Description Criteria for Week 1 to Week 3 Subsections
#     ***Evaluation and Description for Tasks, Assignments, or Activities
#         ***Assessing the effectiveness and efficiency of tasks, assignments, or activities in Week 1, Week 2, and Week 3
#         ***Providing objective descriptions and hypotheses related to tasks, assignments, or activities for each week
#     ***Observations and Events Analysis
#         ***Detailing observations and events for Week 1, Week 2, and Week 3
#         ***Analyzing events or happenings objectively and proposing hypotheses for each week
#         ***Summarizing conclusions drawn from events or happenings in each week
#     ***Connection and Communication Experience Assessment
#         ***Evaluating the effectiveness and efficiency of connection and communication experience in each week
#         ***Describing the student's conclusions and reflections on connection and communication with others and organizations for Week 1, Week 2, and Week 3
#         ***Discussing the student's feelings about connection and communication experiences and highlighting how these experiences will benefit the student in future endeavors for each week
# 19
# user:The new provided rubric criterion is:
# Division into Week 1 to Week 3 Subsections (essential)
#  follow the instructions of this thread and examples (provided at the first messages of this thread) to generate the sub-criteria for the next criterion
# 20
# assistant:***Division into Week 1 to Week 3 Subsections (essential)
#     ***Week 1 Subsection Analysis
#         ***Evaluation and Description for Tasks, Assignments, or Activities in Week 1
#         ***Observations and Events Analysis for Week 1
#         ***Connection and Communication Experience Evaluation in Week 1
#     ***Week 2 Subsection Analysis
#         ***Evaluation and Description for Tasks, Assignments, or Activities in Week 2
#         ***Observations and Events Analysis for Week 2
#         ***Connection and Communication Experience Evaluation in Week 2
#     ***Week 3 Subsection Analysis
#         ***Evaluation and Description for Tasks, Assignments, or Activities in Week 3
#         ***Observations and Events Analysis for Week 3
#         ***Connection and Communication Experience Evaluation in Week 3
# 20

# %%
from GPT_assistant.topic_modelling import TM_Assistant
assistant = TM_Assistant()
print(assistant.thread_id)
# Out:
# thread_YPzW2ajJEPBJrCAJ4Qn8DXkY

# %%
from GPT_assistant.topic_modelling import TM_Assistant
assistant = TM_Assistant()
assistant.add_message_to_thread("very good, do agian for this criteria is:\n" + "The document should have Plan of your internship program Scetion (essential) \n Plan of your internship program Scetion sould cover these contents: \n a. A brief introduction of the branch/ area office of the organization where you did your internship \n b. Starting and ending dates of your internship")
output = assistant.run_assistant_single_time()

# %%
messages = assistant.client.beta.threads.messages.list(
    thread_id = assistant.thread_id,
    )
i=0
for message in reversed (messages.data):
  i=i+1
  print(i)
  print(message.role + ":" + message.content[0].text.value)
print (len (messages.data))
# Out:
# 1
# user:Example: **Input:**
#
# The personal development section must be divided into four quarterly parts: Q1, Q2, Q3, and Q4.
#
# **Output:**
#
# ***The personal development section must be divided into four quarterly parts: Q1, Q2, Q3, and Q4.
# 2
# user:Example: **Input:**
#
# semester  S1 should consist of entries that address specifics from that period, encompassing at least one major project or initiative
#
#         For all projects and initiatives, describe:
#         -The personal growth experienced during the project
#         -Evidence of skill application and integration during the project
#
# **Output:**
#
# ***semester  S1 should consist of entries that address specifics from that period, encompassing at least one major project or initiative
#
#         *** For all projects and initiatives of semester S1, describe:
#         -The personal growth experienced during the project
#         -Evidence of skill application and integration during the project
# 3
# user:Example: **Input:**
#
# For all projects and initiatives of semester S1, describe:
#         -The personal growth experienced during the project
#         -Evidence of skill application and integration during the project
#
# **Output:**
#
# *** For all projects and initiatives of semester S1, describe:
#         -The personal growth experienced during the project
#
#         *** For all projects and initiatives of semester S1, describe:
#         -Evidence of skill application and integration during the project
# 4
# user:Example: **Input:**
#
# semester  S1 should consist of entries that address specifics from that period, encompassing at least one major project or initiative
#
# **Output:**
#
# ***semester  S1 should consist of entries that address specifics from that period, encompassing at least one major project or initiative
# 5
# user:Example: **Input:**
#
# Evaluate the effectiveness and efficiency of the tasks or assignments or activities
#
# **Output:**
#
# ***Evaluate the effectiveness and efficiency of the tasks or assignments or activities
# 6
# user:Example: **Input:**
#
# Analyze the student's own performance as a learner relted to connection and Communication expreince with others and organizations
#
# **Output:**
#
# ***Analyze the student's own performance as a learner relted to connection and Communication expreince with others and organizations
# 7
# user:Example: **Input:**
#
# Plan how the information related to connection and Communication expreince with others and organizations will be useful to the students
#
# **Output:**
#
# ***Plan how the information related to connection and Communication expreince with others and organizations will be useful to the students
# 8
# assistant:***Plan how the information related to connection and Communication experience with others and organizations will be useful to the students
# 9
# user:The new provided rubric criterion is:
# The document should be divided to 3 subsections from week 1 to week 3 subsections (essemtial)
#
# for all subsections related to weeks from 1 to 3, the subsections should cover related information about 1- at least one assignment or tasks or activities 2- at least one happenings or events or observation 3- at least one connection and Communication experience with others and organizations.
#  follow the instructions of this thread and examples (provided at the first messages of this thread) to generate the sub-criteria for the new provided criterion
# 10
# assistant:***The document should be divided into 3 subsections from week 1 to week 3 (essential)
#
#         ***For all subsections related to week 1, 2, and 3, the subsections should cover information about:
#         1- At least one assignment or task or activity
#         2- At least one happening or event or observation
#         3- At least one connection and communication experience with others and organizations
# 11
# user:The new provided rubric criterion is:
# The document should be divided to 3 subsections from week 1 to week 3 subsections (essemtial)
#
# for all subsections related to weeks from 1 to 3, the subsections should cover related information about 1- at least one assignment or tasks or activities 2- at least one happenings or events or observation 3- at least one connection and Communication experience with others and organizations.
#  follow the instructions of this thread and examples (provided at the first messages of this thread) to generate the sub-criteria for the new provided criterion
# 12
# assistant:***The document should be divided into 3 subsections from week 1 to week 3 (essential)
#
#         ***For all subsections related to weeks from 1 to 3, the subsection should cover information about:
#         1- At least one assignment or tasks or activities
#         2- At least one happenings or events or observations
#         3- At least one connection and Communication experience with others and organizations.
# 13
# user:The new provided rubric criterion is:
# For all subsection week 1 to week 3 the information related to 1- assignment or tasks or activities 2- happenings or events or observation 3- connection and Communication experience with others and organizations should cover these contents:
#
# for all tasks and assignments and activities, describe:
# - Evaluate the effectiveness and efficiency of the tasks or assignments or activities
# -Describe objectively, hypotheses of the tasks or assignments or activities
#
#
# for all events or happening or observation:
# - answer “What did you, see, read, hear etc.? related to events or happening or observation
# - describe Objectivity and hypotheses of events or happening or observation
# - Describe the student's conclusions of events or happening or observation
#
#
# For all connection and Communication experience with others and organizations:
# - Evaluate the effectiveness and efficiency of connection and Communication experience with others and organizations
# - Describe the student's conclusions about connection and Communication experience with others and organizations
# - Describe the student's feelings about connection and Communication experience with others and organizations
# -Describe In what ways the learning experience related to connection and Communication experience with others and organizations will serve the student in his/her future
#  follow the instructions of this thread and examples (provided at the first messages of this thread) to generate the sub-criteria for the new provided criterion
# 14
# assistant:***For all subsections from week 1 to week 3, the information related to assignment or tasks or activities, happenings or events or observations, and connection and Communication experience with others and organizations should cover these contents:
#
#         ***For all tasks, assignments, and activities:
#         - Evaluate the effectiveness and efficiency of the tasks or assignments or activities
#         - Describe objectively, hypotheses of the tasks or assignments or activities
#
#         ***For all events or happenings or observations:
#         - Answer “What did you see, read, hear," etc., related to events or happenings or observations
#         - Describe objectivity and hypotheses of events or happenings or observations
#         - Describe the student's conclusions of events or happenings or observations
#
#         ***For all connection and Communication experience with others and organizations:
#         - Evaluate the effectiveness and efficiency of connection and Communication experience with others and organizations
#         - Describe the student's conclusions about connection and Communication experience with others and organizations
#         - Describe the student's feelings about connection and Communication experience with others and organizations
#         - Describe In what ways the learning experience related to connection and Communication experience with others and organizations will serve the student in his/her future
# 15
# user:very good, do agian for this criteria is:
# The document should have Plan of your internship program Scetion (essential)
#  Plan of your internship program Scetion sould cover these contents:
#  a. A brief introduction of the branch/ area office of the organization where you did your internship
#  b. Starting and ending dates of your internship
# 16
# assistant:***The document should have a Plan of your internship program Section (essential)
#
#         ***Plan of your internship program Section should cover these contents:
#         a. A brief introduction of the branch/ area office of the organization where you did your internship
#         b. Starting and ending dates of your internship
# 17
# user:very good, do agian for this criteria is:
# The document should have Plan of your internship program Scetion (essential)
#  Plan of your internship program Scetion sould cover these contents:
#  a. A brief introduction of the branch/ area office of the organization where you did your internship
#  b. Starting and ending dates of your internship
# 18
# assistant:*** The document should have a Plan of your internship program Section (essential)
#
#         ***Plan of your internship program Section should cover:
#         a. A brief introduction of the branch/ area office of the organization where you did your internship
#         b. Starting and ending dates of your internship
# 19
# user:very good, do agian for this criteria is:
# The document should have Plan of your internship program Scetion (essential)
#  Plan of your internship program Scetion sould cover these contents:
#  a. A brief introduction of the branch/ area office of the organization where you did your internship
#  b. Starting and ending dates of your internship
# 20
# assistant:The document should have a Plan of your internship program Section (essential)
#
#         ***Plan of your internship program Section should cover these contents:
#         a. A brief introduction of the branch/ area office of the organization where you did your internship
#         b. Starting and ending dates of your internship
# 20

# %%
import json
import pandas as pd
def load_json(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data
def flatten_tree(data):
    # This will hold all our nodes in a flat structure
    rows = []

    # A recursive function to process each node
    def process_node(node):
        row = {
            "id": node['id'],
            "leaf": node['leaf'],
            "criteria": node['criteria'],
            "criteria_simplified_version": node['criteria_simplified_version'],
            "separate_criteria_number": node['separate_criteria_number'],
            "title": node['title'],
            "related_answer_section": node['related_answer_section'],
            "score_source_ID": node['score_source_ID'],
            "score_source": node['score_source'],
            "influence_type": node['influence_type'],
            "influence_on_scoring": node['influence_on_scoring'],
            "list_sub_condition_score": node['list_sub_condition_score'],
            "score_breakdown": node['score_breakdown'],
            "matching_percentage": node['matching_percentage'],
            "reasons": node['reasons'],
            "score_source_percentage": node['score_source_percentage']
        }
        rows.append(row)

        # Process each child
        for child in node.get('children', []):
            process_node(child)

    process_node(data)
    return rows
# Out:
# c:\Users\MSD\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
filename = ".\output\Sample_RKT.josn"
tree_data = load_json(filename)
flat_data = flatten_tree(tree_data)
df = pd.DataFrame(flat_data)
df.to_excel('.\output\RKT.xlsx', index=False)
